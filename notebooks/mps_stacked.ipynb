# %%
import sys
sys.path.append("../")

# %%
import torch
from qmpsqsc.models import mpsqsc
from qmpsqsc.models import qmps
from importlib import reload

reload(mpsqsc)
# Out:
# <module 'qmpsqsc.models.mpsqsc' from '/Users/keisuke/Documents/projects/mps4qsc/notebooks/../qmpsqsc/models/mpsqsc/__init__.py'>

# %%
import torch.nn.functional as F

L = 120
chi = 2
d = 2
qscr = mpsqsc.MpsQsc(L, chi, d, init="stacked", dtype=torch.complex128)
# qscr = qscr.canonicalize(truncate=True)
allup = torch.zeros(L, d, dtype = torch.complex128)
allup[:, 0] = 1.0
alldown = torch.zeros(L, d, dtype = torch.complex128)
alldown[:, 1] = 1.0

allup = mpsqsc.build_product_state(L, d, allup)
alldown = mpsqsc.build_product_state(L, d, alldown)

allup = allup.normalize()
alldown = alldown.normalize()
ghz = mpsqsc.build_ghz_state(L, d, chi, dtype = torch.complex128)
ghz = ghz.normalize()

# %%
qscr.As[0]
qscr.contract_with_state(ghz), qscr.contract_with_state(alldown)
# Out:
# (tensor([1.4272+0.j, 1.4175+0.j], dtype=torch.complex128,
#         grad_fn=<ViewBackward0>),
#  tensor([3.9075e-04+0.j, 2.0045e+00+0.j], dtype=torch.complex128,
#         grad_fn=<ViewBackward0>))

# %%
import random
from typing import List, Tuple, Dict
import torch

@torch.no_grad()
def _ensure_same_device_dtype(state, device, dtype):
    if getattr(state, "device", None) != device or getattr(state, "dtype", None) != dtype:
        state.to(device=device, dtype=dtype)
    return state

def _amps_to_probs_batch(amps: torch.Tensor, eps: float = 1e-12) -> torch.Tensor:
    """
    Convert a batch of amplitudes to Born probabilities.
      amps: (B, 2) real or complex
      returns probs: (B, 2), each row sums to 1
    """
    if torch.is_complex(amps):
        abs_sq = (amps.conj() * amps).real
    else:
        abs_sq = amps * amps
    denom = abs_sq.sum(dim=-1, keepdim=True).clamp_min(eps)
    return abs_sq / denom

def train_classifier_qsc_on_ghz_vs_rho(
    qsc,
    mpsghz,
    mps_allup,
    mps_alldown,
    *,
    steps: int = 2000,
    lr: float = 1e-2,
    batch_size: int = 16,          # kept for API compatibility but ignored
    ghz_fraction: float = 0.5,     # ignored (fixed composition batch)
    weight_decay: float = 0.0,
    grad_clip: float | None = None,
    seed: int | None = 0,
    log_every: int = 100,
) -> Dict[str, List[float]]:
    """
    Train qsc so that it outputs class 1 for GHZ, class 0 for the mixture ρ.

    CHANGE: No softmax. We treat the 2-D output as amplitudes a,
            compute probabilities p_k = |a_k|^2 / sum_j |a_j|^2,
            and minimize NLL:  -log p_y.

    Each step uses a fixed batch of 4 samples:
        [GHZ, GHZ, all-up, all-down] with labels [1, 1, 0, 0].
    """
    if seed is not None:
        torch.manual_seed(seed)
        random.seed(seed)

    device, dtype = qsc.device, qsc.dtype

    # Ensure states match qsc's device/dtype
    _ensure_same_device_dtype(mpsghz, device, dtype)
    _ensure_same_device_dtype(mps_allup, device, dtype)
    _ensure_same_device_dtype(mps_alldown, device, dtype)

    # Collect parameters (works for nn.Module or your minimal class exposing .parameters())
    try:
        params = list(qsc.parameters())
        if len(params) == 0:
            params = list(getattr(qsc, "As", []))
    except Exception:
        params = list(getattr(qsc, "As", []))

    optim = torch.optim.Adam(params, lr=lr, weight_decay=weight_decay)

    history: Dict[str, List[float]] = {"loss": [], "acc": []}

    # Fixed batch content per step
    fixed_states = [mpsghz, mpsghz, mps_allup, mps_alldown]
    fixed_labels = torch.tensor([1, 1, 0, 0], dtype=torch.long, device=device)
    # fixed_labels = torch.tensor([0, 0, 1, 1], dtype=torch.long, device=device)

    for step in range(1, steps + 1):
        if hasattr(qsc, "train"):
            qsc.train()

        optim.zero_grad(set_to_none=True)

        # Optionally shuffle the 4 examples each step
        idx = [0, 1, 2, 3]
        # random.shuffle(idx)
        states = [fixed_states[i] for i in idx]
        y = fixed_labels[idx]                       # shape (4,)

        # ---- forward: amplitudes -> Born probs ----
        amps_list = [qsc.contract_with_state(st) for st in states]   # each (2,)
        amps_batch = torch.stack(amps_list, dim=0)                   # (4, 2)
        probs = _amps_to_probs_batch(amps_batch)                     # (4, 2)
        print(probs)

        # ---- loss: negative log-likelihood on target class ----
        eps = 1e-12
        p_y = probs.gather(1, y.view(-1, 1)).squeeze(1)              # (4,)
        nll = -torch.log(p_y.clamp_min(eps)).mean()
        loss = nll

        # ---- backward/step ----
        loss.backward()
        # if grad_clip is not None and len(params) > 0:
        #     torch.nn.utils.clip_grad_norm_(params, max_norm=grad_clip)
        optim.step()

        # ---- metric: accuracy by argmax over Born probs ----
        with torch.no_grad():
            pred = probs.argmax(dim=-1)                              # (4,)
            acc = (pred == y).float().mean().item()

        history["loss"].append(float(loss.item()))
        history["acc"].append(acc)

        if (log_every is not None) and (step % log_every == 0):
            print(f"[step {step:5d}] loss={loss.item():.6f}  acc={acc:.3f}")

    return history

# %%
# You already created these:
# L = 10; chi = 2; d = 2
# qsc = mps_classifier.MpsQsc(L, chi, d)
# mps_allup, mps_alldown, mpsghz prepared and normalized
# qsc = mps_classifier.build_qsc_from_mpstate(mpsghz)   # if you prefer that init

hist = train_classifier_qsc_on_ghz_vs_rho(
    qscr,
    mpsghz=ghz,
    mps_allup=allup,
    mps_alldown=alldown,
    steps=150,
    lr=1e-2,
    weight_decay=0.0,
    grad_clip=1.0,   # optional
    seed=0,
    log_every=1,
)
# Out:
# tensor([[5.0342e-01, 4.9658e-01],
#         [5.0342e-01, 4.9658e-01],
#         [1.0000e+00, 2.6433e-09],
#         [3.7999e-08, 1.0000e+00]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step     1] loss=4.621432  acc=0.250
# tensor([[3.5010e-04, 9.9965e-01],
#         [3.5010e-04, 9.9965e-01],
#         [9.9990e-01, 1.0311e-04],
#         [1.0184e-04, 9.9990e-01]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step     2] loss=2.298225  acc=0.750
# tensor([[3.0089e-04, 9.9970e-01],
#         [3.0089e-04, 9.9970e-01],
#         [9.9971e-01, 2.8629e-04],
#         [2.8855e-04, 9.9971e-01]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step     3] loss=2.037879  acc=0.750
# tensor([[5.0865e-04, 9.9949e-01],
#         [5.0865e-04, 9.9949e-01],
#         [9.9952e-01, 4.8080e-04],
#         [5.0726e-04, 9.9949e-01]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step     4] loss=1.896995  acc=0.750
# tensor([[7.4197e-04, 9.9926e-01],
#         [7.4197e-04, 9.9926e-01],
#         [9.9939e-01, 6.1443e-04],
#         [7.4175e-04, 9.9926e-01]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step     5] loss=1.802150  acc=0.750
# tensor([[9.8476e-04, 9.9902e-01],
#         [9.8476e-04, 9.9902e-01],
#         [9.9964e-01, 3.5501e-04],
#         [9.8471e-04, 9.9902e-01]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step     6] loss=1.731372  acc=0.750
# tensor([[0.0012, 0.9988],
#         [0.0012, 0.9988],
#         [0.9979, 0.0021],
#         [0.0012, 0.9988]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step     7] loss=1.675874  acc=0.750
# tensor([[0.0015, 0.9985],
#         [0.0015, 0.9985],
#         [0.8250, 0.1750],
#         [0.0015, 0.9985]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step     8] loss=1.677376  acc=0.750
# tensor([[0.0017, 0.9983],
#         [0.0017, 0.9983],
#         [0.9955, 0.0045],
#         [0.0017, 0.9983]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step     9] loss=1.591415  acc=0.750
# tensor([[0.0020, 0.9980],
#         [0.0020, 0.9980],
#         [0.9954, 0.0046],
#         [0.0020, 0.9980]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    10] loss=1.557708  acc=0.750
# tensor([[0.0022, 0.9978],
#         [0.0022, 0.9978],
#         [0.9954, 0.0046],
#         [0.0022, 0.9978]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    11] loss=1.528036  acc=0.750
# tensor([[0.0025, 0.9975],
#         [0.0025, 0.9975],
#         [0.9954, 0.0046],
#         [0.0025, 0.9975]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    12] loss=1.501561  acc=0.750
# tensor([[0.0027, 0.9973],
#         [0.0027, 0.9973],
#         [0.9954, 0.0046],
#         [0.0027, 0.9973]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    13] loss=1.477663  acc=0.750
# tensor([[0.0030, 0.9970],
#         [0.0030, 0.9970],
#         [0.9954, 0.0046],
#         [0.0030, 0.9970]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    14] loss=1.455877  acc=0.750
# tensor([[0.0032, 0.9968],
#         [0.0032, 0.9968],
#         [0.9953, 0.0047],
#         [0.0032, 0.9968]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    15] loss=1.435841  acc=0.750
# tensor([[0.0035, 0.9965],
#         [0.0035, 0.9965],
#         [0.9953, 0.0047],
#         [0.0035, 0.9965]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    16] loss=1.417272  acc=0.750
# tensor([[0.0037, 0.9963],
#         [0.0037, 0.9963],
#         [0.9953, 0.0047],
#         [0.0037, 0.9963]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    17] loss=1.399941  acc=0.750
# tensor([[0.0040, 0.9960],
#         [0.0040, 0.9960],
#         [0.9953, 0.0047],
#         [0.0040, 0.9960]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    18] loss=1.383662  acc=0.750
# tensor([[0.0043, 0.9957],
#         [0.0043, 0.9957],
#         [0.9953, 0.0047],
#         [0.0043, 0.9957]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    19] loss=1.368282  acc=0.750
# tensor([[0.0045, 0.9955],
#         [0.0045, 0.9955],
#         [0.9953, 0.0047],
#         [0.0045, 0.9955]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    20] loss=1.353672  acc=0.750
# tensor([[0.0048, 0.9952],
#         [0.0048, 0.9952],
#         [0.9953, 0.0047],
#         [0.0048, 0.9952]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    21] loss=1.339723  acc=0.750
# tensor([[0.0050, 0.9950],
#         [0.0050, 0.9950],
#         [0.9953, 0.0047],
#         [0.0050, 0.9950]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    22] loss=1.326342  acc=0.750
# tensor([[0.0053, 0.9947],
#         [0.0053, 0.9947],
#         [0.9953, 0.0047],
#         [0.0053, 0.9947]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    23] loss=1.313450  acc=0.750
# tensor([[0.0056, 0.9944],
#         [0.0056, 0.9944],
#         [0.9953, 0.0047],
#         [0.0056, 0.9944]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    24] loss=1.300975  acc=0.750
# tensor([[0.0059, 0.9941],
#         [0.0059, 0.9941],
#         [0.9953, 0.0047],
#         [0.0059, 0.9941]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    25] loss=1.288857  acc=0.750
# tensor([[0.0062, 0.9938],
#         [0.0062, 0.9938],
#         [0.9953, 0.0047],
#         [0.0062, 0.9938]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    26] loss=1.277043  acc=0.750
# tensor([[0.0064, 0.9936],
#         [0.0064, 0.9936],
#         [0.9953, 0.0047],
#         [0.0064, 0.9936]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    27] loss=1.265484  acc=0.750
# tensor([[0.0067, 0.9933],
#         [0.0067, 0.9933],
#         [0.9953, 0.0047],
#         [0.0067, 0.9933]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    28] loss=1.254138  acc=0.750
# tensor([[0.0071, 0.9929],
#         [0.0071, 0.9929],
#         [0.9953, 0.0047],
#         [0.0071, 0.9929]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    29] loss=1.242966  acc=0.750
# tensor([[0.0074, 0.9926],
#         [0.0074, 0.9926],
#         [0.9953, 0.0047],
#         [0.0074, 0.9926]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    30] loss=1.231934  acc=0.750
# tensor([[0.0077, 0.9923],
#         [0.0077, 0.9923],
#         [0.9953, 0.0047],
#         [0.0077, 0.9923]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    31] loss=1.221009  acc=0.750
# tensor([[0.0081, 0.9919],
#         [0.0081, 0.9919],
#         [0.9953, 0.0047],
#         [0.0081, 0.9919]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    32] loss=1.210164  acc=0.750
# tensor([[0.0084, 0.9916],
#         [0.0084, 0.9916],
#         [0.9953, 0.0047],
#         [0.0084, 0.9916]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    33] loss=1.199371  acc=0.750
# tensor([[0.0088, 0.9912],
#         [0.0088, 0.9912],
#         [0.9954, 0.0046],
#         [0.0088, 0.9912]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    34] loss=1.188605  acc=0.750
# tensor([[0.0092, 0.9908],
#         [0.0092, 0.9908],
#         [0.9954, 0.0046],
#         [0.0092, 0.9908]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    35] loss=1.177843  acc=0.750
# tensor([[0.0096, 0.9904],
#         [0.0096, 0.9904],
#         [0.9954, 0.0046],
#         [0.0096, 0.9904]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    36] loss=1.167065  acc=0.750
# tensor([[0.0100, 0.9900],
#         [0.0100, 0.9900],
#         [0.9954, 0.0046],
#         [0.0101, 0.9899]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    37] loss=1.156248  acc=0.750
# tensor([[0.0105, 0.9895],
#         [0.0105, 0.9895],
#         [0.9954, 0.0046],
#         [0.0105, 0.9895]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    38] loss=1.145374  acc=0.750
# tensor([[0.0110, 0.9890],
#         [0.0110, 0.9890],
#         [0.9954, 0.0046],
#         [0.0110, 0.9890]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    39] loss=1.134425  acc=0.750
# tensor([[0.0115, 0.9885],
#         [0.0115, 0.9885],
#         [0.9954, 0.0046],
#         [0.0115, 0.9885]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    40] loss=1.123381  acc=0.750
# tensor([[0.0120, 0.9880],
#         [0.0120, 0.9880],
#         [0.9954, 0.0046],
#         [0.0120, 0.9880]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    41] loss=1.112226  acc=0.750
# tensor([[0.0126, 0.9874],
#         [0.0126, 0.9874],
#         [0.9954, 0.0046],
#         [0.0126, 0.9874]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    42] loss=1.100943  acc=0.750
# tensor([[0.0132, 0.9868],
#         [0.0132, 0.9868],
#         [0.9954, 0.0046],
#         [0.0132, 0.9868]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    43] loss=1.089515  acc=0.750
# tensor([[0.0139, 0.9861],
#         [0.0139, 0.9861],
#         [0.9954, 0.0046],
#         [0.0139, 0.9861]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    44] loss=1.077925  acc=0.750
# tensor([[0.0145, 0.9855],
#         [0.0145, 0.9855],
#         [0.9954, 0.0046],
#         [0.0145, 0.9855]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    45] loss=1.066157  acc=0.750
# tensor([[0.0153, 0.9847],
#         [0.0153, 0.9847],
#         [0.9954, 0.0046],
#         [0.0153, 0.9847]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    46] loss=1.054193  acc=0.750
# tensor([[0.0161, 0.9839],
#         [0.0161, 0.9839],
#         [0.9954, 0.0046],
#         [0.0161, 0.9839]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    47] loss=1.042017  acc=0.750
# tensor([[0.0169, 0.9831],
#         [0.0169, 0.9831],
#         [0.9954, 0.0046],
#         [0.0169, 0.9831]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    48] loss=1.029612  acc=0.750
# tensor([[0.0178, 0.9822],
#         [0.0178, 0.9822],
#         [0.9954, 0.0046],
#         [0.0178, 0.9822]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    49] loss=1.016960  acc=0.750
# tensor([[0.0188, 0.9812],
#         [0.0188, 0.9812],
#         [0.9954, 0.0046],
#         [0.0188, 0.9812]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    50] loss=1.004042  acc=0.750
# tensor([[0.0199, 0.9801],
#         [0.0199, 0.9801],
#         [0.9954, 0.0046],
#         [0.0199, 0.9801]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    51] loss=0.990840  acc=0.750
# tensor([[0.0210, 0.9790],
#         [0.0210, 0.9790],
#         [0.9954, 0.0046],
#         [0.0210, 0.9790]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    52] loss=0.977335  acc=0.750
# tensor([[0.0223, 0.9777],
#         [0.0223, 0.9777],
#         [0.9954, 0.0046],
#         [0.0223, 0.9777]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    53] loss=0.963506  acc=0.750
# tensor([[0.0236, 0.9764],
#         [0.0236, 0.9764],
#         [0.9954, 0.0046],
#         [0.0236, 0.9764]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    54] loss=0.949331  acc=0.750
# tensor([[0.0251, 0.9749],
#         [0.0251, 0.9749],
#         [0.9954, 0.0046],
#         [0.0251, 0.9749]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    55] loss=0.934789  acc=0.750
# tensor([[0.0268, 0.9732],
#         [0.0268, 0.9732],
#         [0.9954, 0.0046],
#         [0.0268, 0.9732]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    56] loss=0.919857  acc=0.750
# tensor([[0.0286, 0.9714],
#         [0.0286, 0.9714],
#         [0.9954, 0.0046],
#         [0.0286, 0.9714]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    57] loss=0.904509  acc=0.750
# tensor([[0.0306, 0.9694],
#         [0.0306, 0.9694],
#         [0.9954, 0.0046],
#         [0.0306, 0.9694]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    58] loss=0.888720  acc=0.750
# tensor([[0.0328, 0.9672],
#         [0.0328, 0.9672],
#         [0.9954, 0.0046],
#         [0.0328, 0.9672]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    59] loss=0.872464  acc=0.750
# tensor([[0.0352, 0.9648],
#         [0.0352, 0.9648],
#         [0.9954, 0.0046],
#         [0.0352, 0.9648]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    60] loss=0.855712  acc=0.750
# tensor([[0.0379, 0.9621],
#         [0.0379, 0.9621],
#         [0.9954, 0.0046],
#         [0.0379, 0.9621]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    61] loss=0.838436  acc=0.750
# tensor([[0.0410, 0.9590],
#         [0.0410, 0.9590],
#         [0.9954, 0.0046],
#         [0.0410, 0.9590]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    62] loss=0.820605  acc=0.750
# tensor([[0.0445, 0.9555],
#         [0.0445, 0.9555],
#         [0.9954, 0.0046],
#         [0.0445, 0.9555]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    63] loss=0.802192  acc=0.750
# tensor([[0.0484, 0.9516],
#         [0.0484, 0.9516],
#         [0.9954, 0.0046],
#         [0.0484, 0.9516]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    64] loss=0.783166  acc=0.750
# tensor([[0.0528, 0.9472],
#         [0.0528, 0.9472],
#         [0.9954, 0.0046],
#         [0.0528, 0.9472]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    65] loss=0.763500  acc=0.750
# tensor([[0.0579, 0.9421],
#         [0.0579, 0.9421],
#         [0.9955, 0.0045],
#         [0.0579, 0.9421]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    66] loss=0.743172  acc=0.750
# tensor([[0.0638, 0.9362],
#         [0.0638, 0.9362],
#         [0.9955, 0.0045],
#         [0.0638, 0.9362]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    67] loss=0.722164  acc=0.750
# tensor([[0.0706, 0.9294],
#         [0.0706, 0.9294],
#         [0.9955, 0.0045],
#         [0.0706, 0.9294]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    68] loss=0.700471  acc=0.750
# tensor([[0.0785, 0.9215],
#         [0.0785, 0.9215],
#         [0.9955, 0.0045],
#         [0.0785, 0.9215]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    69] loss=0.678104  acc=0.750
# tensor([[0.0879, 0.9121],
#         [0.0879, 0.9121],
#         [0.9955, 0.0045],
#         [0.0879, 0.9121]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    70] loss=0.655101  acc=0.750
# tensor([[0.0989, 0.9011],
#         [0.0989, 0.9011],
#         [0.9955, 0.0045],
#         [0.0989, 0.9011]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    71] loss=0.631543  acc=0.750
# tensor([[0.1122, 0.8878],
#         [0.1122, 0.8878],
#         [0.9955, 0.0045],
#         [0.1122, 0.8878]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    72] loss=0.607572  acc=0.750
# tensor([[0.1281, 0.8719],
#         [0.1281, 0.8719],
#         [0.9955, 0.0045],
#         [0.1281, 0.8719]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    73] loss=0.583429  acc=0.750
# tensor([[0.1474, 0.8526],
#         [0.1474, 0.8526],
#         [0.9955, 0.0045],
#         [0.1474, 0.8526]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    74] loss=0.559501  acc=0.750
# tensor([[0.1710, 0.8290],
#         [0.1710, 0.8290],
#         [0.9955, 0.0045],
#         [0.1710, 0.8290]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    75] loss=0.536399  acc=0.750
# tensor([[0.2000, 0.8000],
#         [0.2000, 0.8000],
#         [0.9955, 0.0045],
#         [0.2000, 0.8000]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    76] loss=0.515062  acc=0.750
# tensor([[0.2355, 0.7645],
#         [0.2355, 0.7645],
#         [0.9955, 0.0045],
#         [0.2355, 0.7645]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    77] loss=0.496894  acc=0.750
# tensor([[0.2787, 0.7213],
#         [0.2787, 0.7213],
#         [0.9955, 0.0045],
#         [0.2787, 0.7213]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    78] loss=0.483882  acc=0.750
# tensor([[0.3297, 0.6703],
#         [0.3297, 0.6703],
#         [0.9955, 0.0045],
#         [0.3297, 0.6703]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    79] loss=0.478527  acc=0.750
# tensor([[0.3864, 0.6136],
#         [0.3864, 0.6136],
#         [0.9955, 0.0045],
#         [0.3864, 0.6136]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    80] loss=0.483050  acc=0.750
# tensor([[0.4423, 0.5577],
#         [0.4423, 0.5577],
#         [0.9955, 0.0045],
#         [0.4423, 0.5577]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    81] loss=0.497020  acc=0.750
# tensor([[0.4857, 0.5143],
#         [0.4857, 0.5143],
#         [0.9955, 0.0045],
#         [0.4857, 0.5143]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    82] loss=0.514137  acc=0.750
# tensor([[0.5064, 0.4936],
#         [0.5064, 0.4936],
#         [0.9955, 0.0045],
#         [0.5064, 0.4936]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    83] loss=0.524226  acc=0.500
# tensor([[0.5026, 0.4974],
#         [0.5026, 0.4974],
#         [0.9955, 0.0045],
#         [0.5026, 0.4974]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    84] loss=0.522275  acc=0.500
# tensor([[0.4802, 0.5198],
#         [0.4802, 0.5198],
#         [0.9955, 0.0045],
#         [0.4802, 0.5198]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    85] loss=0.511638  acc=0.750
# tensor([[0.4472, 0.5528],
#         [0.4472, 0.5528],
#         [0.9955, 0.0045],
#         [0.4472, 0.5528]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    86] loss=0.498672  acc=0.750
# tensor([[0.4107, 0.5893],
#         [0.4107, 0.5893],
#         [0.9955, 0.0045],
#         [0.4107, 0.5893]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    87] loss=0.487993  acc=0.750
# tensor([[0.3756, 0.6244],
#         [0.3756, 0.6244],
#         [0.9955, 0.0045],
#         [0.3756, 0.6244]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    88] loss=0.481398  acc=0.750
# tensor([[0.3445, 0.6555],
#         [0.3445, 0.6555],
#         [0.9955, 0.0045],
#         [0.3445, 0.6555]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    89] loss=0.478703  acc=0.750
# tensor([[0.3186, 0.6814],
#         [0.3186, 0.6814],
#         [0.9956, 0.0044],
#         [0.3186, 0.6814]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    90] loss=0.478865  acc=0.750
# tensor([[0.2978, 0.7022],
#         [0.2978, 0.7022],
#         [0.9956, 0.0044],
#         [0.2979, 0.7021]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    91] loss=0.480702  acc=0.750
# tensor([[0.2819, 0.7181],
#         [0.2819, 0.7181],
#         [0.9956, 0.0044],
#         [0.2819, 0.7181]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    92] loss=0.483232  acc=0.750
# tensor([[0.2702, 0.7298],
#         [0.2702, 0.7298],
#         [0.9956, 0.0044],
#         [0.2702, 0.7298]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    93] loss=0.485755  acc=0.750
# tensor([[0.2621, 0.7379],
#         [0.2621, 0.7379],
#         [0.9956, 0.0044],
#         [0.2621, 0.7379]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    94] loss=0.487825  acc=0.750
# tensor([[0.2573, 0.7427],
#         [0.2573, 0.7427],
#         [0.9956, 0.0044],
#         [0.2573, 0.7427]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    95] loss=0.489201  acc=0.750
# tensor([[0.2554, 0.7446],
#         [0.2554, 0.7446],
#         [0.9956, 0.0044],
#         [0.2554, 0.7446]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    96] loss=0.489793  acc=0.750
# tensor([[0.2560, 0.7440],
#         [0.2560, 0.7440],
#         [0.9956, 0.0044],
#         [0.2560, 0.7440]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    97] loss=0.489614  acc=0.750
# tensor([[0.2588, 0.7412],
#         [0.2588, 0.7412],
#         [0.9956, 0.0044],
#         [0.2588, 0.7412]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    98] loss=0.488757  acc=0.750
# tensor([[0.2638, 0.7362],
#         [0.2638, 0.7362],
#         [0.9956, 0.0044],
#         [0.2638, 0.7362]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step    99] loss=0.487365  acc=0.750
# tensor([[0.2707, 0.7293],
#         [0.2707, 0.7293],
#         [0.9956, 0.0044],
#         [0.2707, 0.7293]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step   100] loss=0.485622  acc=0.750
# tensor([[0.2793, 0.7207],
#         [0.2793, 0.7207],
#         [0.9956, 0.0044],
#         [0.2793, 0.7207]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step   101] loss=0.483731  acc=0.750
# tensor([[0.2894, 0.7106],
#         [0.2894, 0.7106],
#         [0.9956, 0.0044],
#         [0.2894, 0.7106]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step   102] loss=0.481904  acc=0.750
# tensor([[0.3007, 0.6993],
#         [0.3007, 0.6993],
#         [0.9956, 0.0044],
#         [0.3007, 0.6993]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step   103] loss=0.480339  acc=0.750
# tensor([[0.3129, 0.6871],
#         [0.3129, 0.6871],
#         [0.9956, 0.0044],
#         [0.3129, 0.6871]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step   104] loss=0.479199  acc=0.750
# tensor([[0.3254, 0.6746],
#         [0.3254, 0.6746],
#         [0.9956, 0.0044],
#         [0.3254, 0.6746]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step   105] loss=0.478583  acc=0.750
# tensor([[0.3376, 0.6624],
#         [0.3376, 0.6624],
#         [0.9956, 0.0044],
#         [0.3376, 0.6624]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step   106] loss=0.478505  acc=0.750
# tensor([[0.3490, 0.6510],
#         [0.3490, 0.6510],
#         [0.9956, 0.0044],
#         [0.3490, 0.6510]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step   107] loss=0.478880  acc=0.750
# tensor([[0.3587, 0.6413],
#         [0.3587, 0.6413],
#         [0.9956, 0.0044],
#         [0.3587, 0.6413]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step   108] loss=0.479532  acc=0.750
# tensor([[0.3662, 0.6338],
#         [0.3662, 0.6338],
#         [0.9956, 0.0044],
#         [0.3662, 0.6338]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step   109] loss=0.480238  acc=0.750
# tensor([[0.3710, 0.6290],
#         [0.3710, 0.6290],
#         [0.9956, 0.0044],
#         [0.3710, 0.6290]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step   110] loss=0.480781  acc=0.750
# tensor([[0.3729, 0.6271],
#         [0.3729, 0.6271],
#         [0.9957, 0.0043],
#         [0.3729, 0.6271]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step   111] loss=0.481015  acc=0.750
# tensor([[0.3720, 0.6280],
#         [0.3720, 0.6280],
#         [0.9957, 0.0043],
#         [0.3720, 0.6280]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step   112] loss=0.480900  acc=0.750
# tensor([[0.3686, 0.6314],
#         [0.3686, 0.6314],
#         [0.9957, 0.0043],
#         [0.3686, 0.6314]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step   113] loss=0.480500  acc=0.750
# tensor([[0.3633, 0.6367],
#         [0.3633, 0.6367],
#         [0.9957, 0.0043],
#         [0.3633, 0.6367]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step   114] loss=0.479942  acc=0.750
# tensor([[0.3568, 0.6432],
#         [0.3568, 0.6432],
#         [0.9957, 0.0043],
#         [0.3568, 0.6432]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step   115] loss=0.479370  acc=0.750
# tensor([[0.3495, 0.6505],
#         [0.3495, 0.6505],
#         [0.9957, 0.0043],
#         [0.3496, 0.6504]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step   116] loss=0.478899  acc=0.750
# tensor([[0.3422, 0.6578],
#         [0.3422, 0.6578],
#         [0.9957, 0.0043],
#         [0.3422, 0.6578]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step   117] loss=0.478593  acc=0.750
# tensor([[0.3353, 0.6647],
#         [0.3353, 0.6647],
#         [0.9957, 0.0043],
#         [0.3353, 0.6647]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step   118] loss=0.478466  acc=0.750
# tensor([[0.3290, 0.6710],
#         [0.3290, 0.6710],
#         [0.9957, 0.0043],
#         [0.3290, 0.6710]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step   119] loss=0.478490  acc=0.750
# tensor([[0.3237, 0.6763],
#         [0.3237, 0.6763],
#         [0.9957, 0.0043],
#         [0.3238, 0.6762]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step   120] loss=0.478614  acc=0.750
# tensor([[0.3195, 0.6805],
#         [0.3195, 0.6805],
#         [0.9957, 0.0043],
#         [0.3196, 0.6804]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step   121] loss=0.478781  acc=0.750
# tensor([[0.3165, 0.6835],
#         [0.3165, 0.6835],
#         [0.9957, 0.0043],
#         [0.3165, 0.6835]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step   122] loss=0.478941  acc=0.750
# tensor([[0.3146, 0.6854],
#         [0.3146, 0.6854],
#         [0.9957, 0.0043],
#         [0.3146, 0.6854]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step   123] loss=0.479056  acc=0.750
# tensor([[0.3139, 0.6861],
#         [0.3139, 0.6861],
#         [0.9957, 0.0043],
#         [0.3139, 0.6861]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step   124] loss=0.479105  acc=0.750
# tensor([[0.3141, 0.6859],
#         [0.3141, 0.6859],
#         [0.9957, 0.0043],
#         [0.3141, 0.6859]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step   125] loss=0.479085  acc=0.750
# tensor([[0.3154, 0.6846],
#         [0.3154, 0.6846],
#         [0.9957, 0.0043],
#         [0.3154, 0.6846]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step   126] loss=0.479005  acc=0.750
# tensor([[0.3174, 0.6826],
#         [0.3174, 0.6826],
#         [0.9957, 0.0043],
#         [0.3174, 0.6826]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step   127] loss=0.478885  acc=0.750
# tensor([[0.3200, 0.6800],
#         [0.3200, 0.6800],
#         [0.9957, 0.0043],
#         [0.3201, 0.6799]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step   128] loss=0.478749  acc=0.750
# tensor([[0.3232, 0.6768],
#         [0.3232, 0.6768],
#         [0.9957, 0.0043],
#         [0.3232, 0.6768]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step   129] loss=0.478621  acc=0.750
# tensor([[0.3266, 0.6734],
#         [0.3266, 0.6734],
#         [0.9957, 0.0043],
#         [0.3266, 0.6734]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step   130] loss=0.478521  acc=0.750
# tensor([[0.3301, 0.6699],
#         [0.3301, 0.6699],
#         [0.9958, 0.0042],
#         [0.3301, 0.6699]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step   131] loss=0.478460  acc=0.750
# tensor([[0.3335, 0.6665],
#         [0.3335, 0.6665],
#         [0.9958, 0.0042],
#         [0.3335, 0.6665]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step   132] loss=0.478442  acc=0.750
# tensor([[0.3366, 0.6634],
#         [0.3366, 0.6634],
#         [0.9958, 0.0042],
#         [0.3366, 0.6634]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step   133] loss=0.478458  acc=0.750
# tensor([[0.3392, 0.6608],
#         [0.3392, 0.6608],
#         [0.9958, 0.0042],
#         [0.3393, 0.6607]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step   134] loss=0.478498  acc=0.750
# tensor([[0.3413, 0.6587],
#         [0.3413, 0.6587],
#         [0.9958, 0.0042],
#         [0.3413, 0.6587]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step   135] loss=0.478544  acc=0.750
# tensor([[0.3426, 0.6574],
#         [0.3426, 0.6574],
#         [0.9958, 0.0042],
#         [0.3427, 0.6573]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step   136] loss=0.478581  acc=0.750
# tensor([[0.3433, 0.6567],
#         [0.3433, 0.6567],
#         [0.9958, 0.0042],
#         [0.3433, 0.6567]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step   137] loss=0.478601  acc=0.750
# tensor([[0.3433, 0.6567],
#         [0.3433, 0.6567],
#         [0.9958, 0.0042],
#         [0.3433, 0.6567]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step   138] loss=0.478599  acc=0.750
# tensor([[0.3426, 0.6574],
#         [0.3426, 0.6574],
#         [0.9958, 0.0042],
#         [0.3426, 0.6574]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step   139] loss=0.478577  acc=0.750
# tensor([[0.3415, 0.6585],
#         [0.3415, 0.6585],
#         [0.9958, 0.0042],
#         [0.3415, 0.6585]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step   140] loss=0.478542  acc=0.750
# tensor([[0.3399, 0.6601],
#         [0.3399, 0.6601],
#         [0.9958, 0.0042],
#         [0.3399, 0.6601]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step   141] loss=0.478502  acc=0.750
# tensor([[0.3381, 0.6619],
#         [0.3381, 0.6619],
#         [0.9958, 0.0042],
#         [0.3381, 0.6619]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step   142] loss=0.478467  acc=0.750
# tensor([[0.3362, 0.6638],
#         [0.3362, 0.6638],
#         [0.9958, 0.0042],
#         [0.3362, 0.6638]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step   143] loss=0.478441  acc=0.750
# tensor([[0.3343, 0.6657],
#         [0.3343, 0.6657],
#         [0.9958, 0.0042],
#         [0.3343, 0.6657]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step   144] loss=0.478427  acc=0.750
# tensor([[0.3325, 0.6675],
#         [0.3325, 0.6675],
#         [0.9958, 0.0042],
#         [0.3325, 0.6675]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step   145] loss=0.478426  acc=0.750
# tensor([[0.3310, 0.6690],
#         [0.3310, 0.6690],
#         [0.9958, 0.0042],
#         [0.3310, 0.6690]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step   146] loss=0.478432  acc=0.750
# tensor([[0.3298, 0.6702],
#         [0.3298, 0.6702],
#         [0.9958, 0.0042],
#         [0.3298, 0.6702]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step   147] loss=0.478443  acc=0.750
# tensor([[0.3289, 0.6711],
#         [0.3289, 0.6711],
#         [0.9958, 0.0042],
#         [0.3289, 0.6711]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step   148] loss=0.478454  acc=0.750
# tensor([[0.3283, 0.6717],
#         [0.3283, 0.6717],
#         [0.9958, 0.0042],
#         [0.3283, 0.6717]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step   149] loss=0.478461  acc=0.750
# tensor([[0.3281, 0.6719],
#         [0.3281, 0.6719],
#         [0.9959, 0.0041],
#         [0.3282, 0.6718]], dtype=torch.float64, grad_fn=<DivBackward0>)
# [step   150] loss=0.478463  acc=0.750

# %%
qsc_2 = qsc.truncate_bond_dimension(2)

# %%
qsc_2.save_to("data/qsc_2.pth")

# %%
blob = torch.load("data/qsc_2.pth")

# %%
blob
# Out:
# {'format': 'mps_v1',
#  'class_name': 'MpsQsc',
#  'L': 100,
#  'd': 2,
#  'chi': 2,
#  'out_dim': 2,
#  'optimize': 'random-greedy',
#  'requires_grad': True,
#  'training': True,
#  'As': [tensor([[0.9998, 0.0000],
#           [0.0000, 1.0002]], dtype=torch.float64),
#   tensor([[[0.0000e+00, 9.9977e-01],
#            [0.0000e+00, 0.0000e+00]],
#
#           [[2.2204e-16, 0.0000e+00],
#            [1.0002e+00, 0.0000e+00]]], dtype=torch.float64),
#   tensor([[[ 0.0000,  0.0000],
#            [ 0.0000,  1.0002]],
#
#           [[-0.9998,  0.0000],
#            [ 0.0000,  0.0000]]], dtype=torch.float64),
#   tensor([[[ 0.0000e+00,  9.9977e-01],
#            [ 0.0000e+00,  0.0000e+00]],
#
#           [[ 2.2204e-16,  0.0000e+00],
#            [-1.0002e+00,  0.0000e+00]]], dtype=torch.float64),
#   tensor([[[0.0000, 0.0000],
#            [0.0000, 1.0002]],
#
#           [[0.9998, 0.0000],
#            [0.0000, 0.0000]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[ 9.9977e-01,  7.3196e-06],
#            [ 0.0000e+00,  0.0000e+00]],
#
#           [[ 0.0000e+00,  0.0000e+00],
#            [-1.7083e-05,  1.0002e+00]]], dtype=torch.float64),
#   tensor([[[ 0.0000e+00, -9.9977e-01],
#            [ 5.0972e-04,  0.0000e+00]],
#
#           [[ 0.0000e+00,  4.6826e-04],
#            [-1.0002e+00,  0.0000e+00]]], dtype=torch.float64),
#   tensor([[[ 0.0000,  0.0000],
#            [ 0.0000,  1.0002]],
#
#           [[-0.9998,  0.0000],
#            [ 0.0000,  0.0000]]], dtype=torch.float64),
#   tensor([[[ 0.9998,  0.0000],
#            [ 0.0000,  0.0000]],
#
#           [[ 0.0000,  0.0000],
#            [ 0.0000, -1.0002]]], dtype=torch.float64),
#   tensor([[[9.9977e-01, 0.0000e+00],
#            [0.0000e+00, 0.0000e+00]],
#
#           [[0.0000e+00, 2.2204e-16],
#            [0.0000e+00, 1.0002e+00]]], dtype=torch.float64),
#   tensor([[[1.7010e-05, 9.9977e-01],
#            [0.0000e+00, 0.0000e+00]],
#
#           [[0.0000e+00, 0.0000e+00],
#            [1.0002e+00, 0.0000e+00]]], dtype=torch.float64),
#   tensor([[[ 2.2204e-16, -5.0950e-04],
#            [ 1.0002e+00,  0.0000e+00]],
#
#           [[-1.7237e-18,  9.9977e-01],
#            [ 0.0000e+00,  0.0000e+00]]], dtype=torch.float64),
#   tensor([[[-3.4362e-18,  0.0000e+00],
#            [ 0.0000e+00,  1.0002e+00]],
#
#           [[ 9.9977e-01,  0.0000e+00],
#            [ 0.0000e+00,  0.0000e+00]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[9.9977e-01, 0.0000e+00],
#            [0.0000e+00, 0.0000e+00]],
#
#           [[0.0000e+00, 3.3307e-16],
#            [0.0000e+00, 1.0002e+00]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[9.9977e-01, 0.0000e+00],
#            [0.0000e+00, 0.0000e+00]],
#
#           [[0.0000e+00, 3.3307e-16],
#            [0.0000e+00, 1.0002e+00]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[9.9977e-01, 0.0000e+00],
#            [0.0000e+00, 0.0000e+00]],
#
#           [[0.0000e+00, 3.3307e-16],
#            [0.0000e+00, 1.0002e+00]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[ 9.9977e-01,  0.0000e+00],
#            [ 0.0000e+00,  0.0000e+00]],
#
#           [[ 0.0000e+00,  3.3307e-16],
#            [ 0.0000e+00, -1.0002e+00]]], dtype=torch.float64),
#   tensor([[[9.9977e-01, 0.0000e+00],
#            [0.0000e+00, 0.0000e+00]],
#
#           [[0.0000e+00, 2.2204e-16],
#            [0.0000e+00, 1.0002e+00]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[9.9977e-01, 0.0000e+00],
#            [0.0000e+00, 0.0000e+00]],
#
#           [[0.0000e+00, 2.2204e-16],
#            [0.0000e+00, 1.0002e+00]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[9.9977e-01, 2.3853e-22],
#            [0.0000e+00, 0.0000e+00]],
#
#           [[0.0000e+00, 0.0000e+00],
#            [0.0000e+00, 1.0002e+00]]], dtype=torch.float64),
#   tensor([[[ 9.9977e-01,  5.3406e-07],
#            [ 0.0000e+00,  0.0000e+00]],
#
#           [[-1.0681e-19,  2.2204e-16],
#            [ 0.0000e+00,  1.0002e+00]]], dtype=torch.float64),
#   tensor([[[-9.9977e-01,  0.0000e+00],
#            [ 0.0000e+00,  0.0000e+00]],
#
#           [[ 1.6693e-04,  0.0000e+00],
#            [ 0.0000e+00, -1.0002e+00]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[9.9977e-01, 0.0000e+00],
#            [0.0000e+00, 0.0000e+00]],
#
#           [[0.0000e+00, 2.2204e-16],
#            [0.0000e+00, 1.0002e+00]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[ 9.9977e-01, -6.0906e-08],
#            [ 0.0000e+00,  0.0000e+00]],
#
#           [[ 0.0000e+00,  0.0000e+00],
#            [ 0.0000e+00, -1.0002e+00]]], dtype=torch.float64),
#   tensor([[[-9.9977e-01,  0.0000e+00],
#            [ 0.0000e+00,  0.0000e+00]],
#
#           [[-2.6114e-05,  0.0000e+00],
#            [ 0.0000e+00, -1.0002e+00]]], dtype=torch.float64),
#   tensor([[[9.9977e-01, 0.0000e+00],
#            [0.0000e+00, 0.0000e+00]],
#
#           [[0.0000e+00, 2.2204e-16],
#            [0.0000e+00, 1.0002e+00]]], dtype=torch.float64),
#   tensor([[[9.9977e-01, 0.0000e+00],
#            [0.0000e+00, 0.0000e+00]],
#
#           [[0.0000e+00, 2.2204e-16],
#            [0.0000e+00, 1.0002e+00]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[9.9977e-01, 1.7666e-06],
#            [0.0000e+00, 0.0000e+00]],
#
#           [[0.0000e+00, 0.0000e+00],
#            [0.0000e+00, 1.0002e+00]]], dtype=torch.float64),
#   tensor([[[-9.9977e-01,  0.0000e+00],
#            [ 0.0000e+00,  0.0000e+00]],
#
#           [[ 3.2370e-04,  0.0000e+00],
#            [ 0.0000e+00, -1.0002e+00]]], dtype=torch.float64),
#   tensor([[[ 9.9977e-01, -1.8272e-06],
#            [ 0.0000e+00,  0.0000e+00]],
#
#           [[ 0.0000e+00,  0.0000e+00],
#            [ 0.0000e+00,  1.0002e+00]]], dtype=torch.float64),
#   tensor([[[-9.9977e-01,  0.0000e+00],
#            [ 0.0000e+00,  0.0000e+00]],
#
#           [[-3.2813e-04,  0.0000e+00],
#            [ 0.0000e+00, -1.0002e+00]]], dtype=torch.float64),
#   tensor([[[9.9977e-01, 1.8807e-06],
#            [0.0000e+00, 0.0000e+00]],
#
#           [[0.0000e+00, 0.0000e+00],
#            [0.0000e+00, 1.0002e+00]]], dtype=torch.float64),
#   tensor([[[-9.9977e-01,  0.0000e+00],
#            [ 0.0000e+00,  0.0000e+00]],
#
#           [[ 3.3190e-04,  0.0000e+00],
#            [ 0.0000e+00, -1.0002e+00]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[ 9.9977e-01, -1.9827e-06],
#            [ 0.0000e+00,  0.0000e+00]],
#
#           [[ 0.0000e+00,  0.0000e+00],
#            [ 0.0000e+00,  1.0002e+00]]], dtype=torch.float64),
#   tensor([[[-9.9977e-01,  0.0000e+00],
#            [ 0.0000e+00,  0.0000e+00]],
#
#           [[-3.3873e-04,  0.0000e+00],
#            [ 0.0000e+00, -1.0002e+00]]], dtype=torch.float64),
#   tensor([[[9.9977e-01, 2.0106e-06],
#            [0.0000e+00, 0.0000e+00]],
#
#           [[0.0000e+00, 0.0000e+00],
#            [0.0000e+00, 1.0002e+00]]], dtype=torch.float64),
#   tensor([[[-9.9977e-01,  0.0000e+00],
#            [ 0.0000e+00,  0.0000e+00]],
#
#           [[ 3.4052e-04,  0.0000e+00],
#            [ 0.0000e+00, -1.0002e+00]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[9.9977e-01, 0.0000e+00],
#            [0.0000e+00, 0.0000e+00]],
#
#           [[0.0000e+00, 2.2204e-16],
#            [0.0000e+00, 1.0002e+00]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[ 9.9977e-01, -2.0049e-06],
#            [ 0.0000e+00,  0.0000e+00]],
#
#           [[ 0.0000e+00,  0.0000e+00],
#            [ 0.0000e+00,  1.0002e+00]]], dtype=torch.float64),
#   tensor([[[-9.9977e-01, -1.9880e-06],
#            [ 0.0000e+00,  0.0000e+00]],
#
#           [[-3.4016e-04,  5.6447e-13],
#            [ 0.0000e+00, -1.0002e+00]]], dtype=torch.float64),
#   tensor([[[-9.9977e-01,  1.9677e-06],
#            [ 0.0000e+00,  0.0000e+00]],
#
#           [[ 3.3907e-04,  5.5396e-13],
#            [-1.7083e-05, -1.0002e+00]]], dtype=torch.float64),
#   tensor([[[-9.9977e-01, -1.9438e-06],
#            [ 0.0000e+00, -5.0972e-04]],
#
#           [[-3.3775e-04,  5.4165e-13],
#            [ 0.0000e+00, -1.0002e+00]]], dtype=torch.float64),
#   tensor([[[-9.9977e-01,  0.0000e+00],
#            [ 0.0000e+00,  0.0000e+00]],
#
#           [[ 3.3618e-04,  0.0000e+00],
#            [ 0.0000e+00, -1.0002e+00]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[9.9977e-01, 0.0000e+00],
#            [0.0000e+00, 0.0000e+00]],
#
#           [[0.0000e+00, 2.2204e-16],
#            [0.0000e+00, 1.0002e+00]]], dtype=torch.float64),
#   tensor([[[ 9.9977e-01, -1.6548e-06],
#            [ 0.0000e+00,  0.0000e+00]],
#
#           [[ 0.0000e+00,  0.0000e+00],
#            [ 0.0000e+00,  1.0002e+00]]], dtype=torch.float64),
#   tensor([[[-9.9977e-01,  0.0000e+00],
#            [ 0.0000e+00,  0.0000e+00]],
#
#           [[-3.1504e-04,  0.0000e+00],
#            [ 0.0000e+00, -1.0002e+00]]], dtype=torch.float64),
#   tensor([[[9.9977e-01, 0.0000e+00],
#            [0.0000e+00, 0.0000e+00]],
#
#           [[0.0000e+00, 2.2204e-16],
#            [0.0000e+00, 1.0002e+00]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[0.9998, 0.0000],
#            [0.0000, 0.0000]],
#
#           [[0.0000, 0.0000],
#            [0.0000, 1.0002]]], dtype=torch.float64),
#   tensor([[[  -0.3117, -177.7871],
#            [   0.0000,    0.0000]],
#
#           [[   0.0000,    0.0000],
#            [  -0.3117,  177.7875]]], dtype=torch.float64)],
#  'metadata': {}}
